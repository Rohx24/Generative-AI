# %%
# !pip -q install openai

from openai import OpenAI

client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key="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"   # <-- paste your key here
)

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "user", "content": "Explain neural networks in 3 lines"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Neural networks are complex systems of interconnected nodes (neurons) that mimic the human brain's structure and function. Each neuron receives inputs, processes them, and outputs a result to other connected neurons, with the network as a whole learning and adapting to its environment through trial and error. This process enables the network to recognize patterns and make informed decisions on its own, with applications in image and speech recognition, natural language processing, and more.
